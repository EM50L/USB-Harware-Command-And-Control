# %% [markdown]
# ![00_logo_shell_&_eh.jpeg](attachment:a324664a-e6fb-44d1-87f4-3eedada8b1d8.jpeg)

# %% [markdown]
# ![01_titulo.jpeg](attachment:4c1e97cf-0590-4836-9347-b8607f6d7405.jpeg)

# %% [markdown]
# ```
# En este taller vamos a "jugar con el USB" desde el lado del cliente. (USB Device)
# Vamos a programar un microcontrolador con Capacidades USB-device.
# Dandole distintas Funciones. Teclado/Raton , HID
# ```
#
# ```
# Ya Existen varios dispositivos de este tipo ya preprogramados:
# Como por ejemplo RuberDucky , flipper usbninja etc...
#
# Nosotros vamos a orientar el taller en las distintas funciones USB
# Que explotan este tipo de dispositivos.
#
# ```

# %% [markdown]
# ![00_Euskalhack.jpeg](attachment:930c2a5e-133e-4854-a1fb-7cd743388a93.jpeg)
